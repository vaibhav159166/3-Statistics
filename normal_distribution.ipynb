# %% [markdown]
# ## Normal Distribution and Z Score: Math and statistics for data science

# %%
import pandas as pd
import seaborn as sn

# %%
df = pd.read_csv("heights.csv")
df.head()
# Out:
#   gender     height
# 0   Male  73.847017
# 1   Male  68.781904
# 2   Male  74.110105
# 3   Male  71.730978
# 4   Male  69.881796

# %% [markdown]
# **(1) Outlier detection and removal using Standard Deviation**

# %%
df.height.describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: height, dtype: float64

# %%
sn.histplot(df.height, kde=True)
# Out:
# <Axes: xlabel='height', ylabel='Count'>

# %%
mean = df.height.mean()
mean
# Out:
# 66.367559754866

# %%
sn.boxplot(df)
# Out:
# <Axes: >

# %% [markdown]
# std_deviation = df.height.std()
# std_deviation

# %%
mean-3*std_deviation
# Out:
# 54.824975392479274

# %%
mean+3*std_deviation
# Out:
# 77.91014411725271

# %% [markdown]
# ## The points ehich are less than -3sigma and greater than +3 sigma is called outliers

# %%
df[(df.height < 54.82) ]
# Out:
#       gender     height
# 6624  Female  54.616858
# 9285  Female  54.263133

# %%
df[(df.height < 54.82) | (df.height > 77.91)]
# Out:
#       gender     height
# 994     Male  78.095867
# 1317    Male  78.462053
# 2014    Male  78.998742
# 3285    Male  78.528210
# 3757    Male  78.621374
# 6624  Female  54.616858
# 9285  Female  54.263133

# %%
# The condition is height < 54.82 or height >77.91

# %%
df[(df.height>77.91)]
# Out:
#      gender     height
# 994    Male  78.095867
# 1317   Male  78.462053
# 2014   Male  78.998742
# 3285   Male  78.528210
# 3757   Male  78.621374

# %%
#

# %%
df_no_outlier = df[(df.height<77.91) & (df.height>54.82)]
df_no_outlier.shape
# Out:
# (9993, 2)

# %% [markdown]
# Let's add a new column in our dataframe for this Z score

# %%
df['zscore'] = ( df.height - df.height.mean() ) / df.height.std()
df.head(5)
# Out:
#   gender     height    zscore
# 0   Male  73.847017  1.943964
# 1   Male  68.781904  0.627505
# 2   Male  74.110105  2.012343
# 3   Male  71.730978  1.393991
# 4   Male  69.881796  0.913375

# %% [markdown]
# Above for first record with height 73.84, z score is 1.94. This means 73.84 is 1.94 standard deviation away from mean

# %%
df.height.mean()
# Out:
# 66.367559754866

# %%
df.height.std()
# Out:
# 3.847528120795573

# %%
(73.84-66.37)/3.84
# Out:
# 1.9453124999999998

# %%
df[df['zscore']>3]
# Out:
#      gender     height    zscore
# 994    Male  78.095867  3.048271
# 1317   Male  78.462053  3.143445
# 2014   Male  78.998742  3.282934
# 3285   Male  78.528210  3.160640
# 3757   Male  78.621374  3.184854

# %%
df[df['zscore']>3]
# Out:
#      gender     height    zscore
# 994    Male  78.095867  3.048271
# 1317   Male  78.462053  3.143445
# 2014   Male  78.998742  3.282934
# 3285   Male  78.528210  3.160640
# 3757   Male  78.621374  3.184854

# %%
df[df['zscore']<3] and df[df['zscore']>-3]
